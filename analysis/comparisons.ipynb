# %% [markdown]
# A comparison of the old model (December 2023), and the new adjustments (February 2024)

# %%
from plotting import get_overlayed_distributions, get_unique_output

sources = ["output_original-20240218-165024.csv", "output_original-20240122-152625.csv"]
colours = ["blue", "red"]
shared_pre_dir = "../output/"

get_overlayed_distributions(sources, shared_pre_dir, colours)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\akesh\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# So it appears the new version of the model has fewer scores that are far from zero.

# %%
sources = ["output_original_auc-20240218-165024.csv", "output_original_auc-20240122-152625.csv"]
get_overlayed_distributions(sources, shared_pre_dir, colours, "auc")
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\akesh\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# But the AUC seems generally better.

# %% [markdown]
# Running the new model a second time (to check consistency, and if we had a weird realisation/ sample), and comparing these two, we have:

# %%
sources_same_version = ["output_original-20240218-165024.csv", "output_original-20240218-170642.csv"]
get_overlayed_distributions(sources_same_version, shared_pre_dir, colours)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\akesh\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# So indeed, the prediction is identical.

# %% [markdown]
# Let us compare the distribution when we insert the missing token

# %%
sources_mis = ["output_3.1-20240208-213247.csv", "output_3.1-20240218-182918.csv"]
get_overlayed_distributions(sources_mis, shared_pre_dir, colours)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\akesh\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# The old model had slightly higher predictions.

# %%
sources_mis_vs_original = ["output_original-20240122-152625.csv", "output_3.1-20240218-182918.csv"]
get_overlayed_distributions(sources_mis_vs_original, shared_pre_dir, colours)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\akesh\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sources_mis_vs_random = ["output_3.1-20240218-182918.csv", get_unique_output("3.2")]
get_overlayed_distributions(sources_mis_vs_random)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\akesh\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sources_mis_vs_double_mis = ["output_3.1-20240218-182918.csv", get_unique_output("3.3")]
get_overlayed_distributions(sources_mis_vs_double_mis)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\akesh\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# So with both bits missing, we predict positive results with far less frequency.

# %%
sources_double_mis_vs_random = [get_unique_output("3.3"), get_unique_output("3.4")]
get_overlayed_distributions(sources_double_mis_vs_random)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\akesh\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# And replacing `\<MIS\>` with `t` does very little to the predictions here. It's as though we provide garbled nonsense?

# %%
from plotting import get_scatter_distributions_comparison, get_unique_output

sources_double_mis_vs_random = [get_unique_output("3.3"), get_unique_output("3.4")]
plt = get_scatter_distributions_comparison(sources_double_mis_vs_random)
plt.xlabel("<MIS>")
plt.ylabel("t")
# Out:
# Text(0, 0.5, 't')

# %%
sources_double_mis_vs_random = [get_unique_output("3.5"), get_unique_output("3.6")]
plt = get_scatter_distributions_comparison(sources_double_mis_vs_random)
plt.xlabel("<MIS>")
plt.ylabel("t")
# Out:
# Text(0, 0.5, 't')

# %% [markdown]
# This was with 2 "missing columns" just like above, but I corrected it so it was CDR3a (not CDR3b) and MHC.

# %%
sources_double_mis_vs_random = [get_unique_output("3.5"), get_unique_output("3.2")]
plt = get_scatter_distributions_comparison(sources_double_mis_vs_random)
plt.xlabel("<MIS>")
plt.ylabel("t")
# Out:
# Text(0, 0.5, 't')
